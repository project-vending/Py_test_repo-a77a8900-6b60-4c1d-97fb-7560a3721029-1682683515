# %%
#

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
url = "https://github.com/project-vending/Py_test_repo-a77a8900-6b60-4c1d-97fb-7560a3721029-1682683515"
df = pd.read_csv(url)

# %%
# Checking for null values
print(df.isnull().sum())

# %%
# Checking for the distribution of the dataset
print(df.describe())

# %%
# Plotting a histogram for each column
df.hist(grid=False, bins=10, figsize=(10,10), color='

# %%
#86bf91', rwidth=0.9)

# %%
# Adding titles and labels to the plot
plt.suptitle('Histograms of each column', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Using seaborn library to plot a heatmap for correlation matrix
corr = df.corr()
sns.heatmap(corr, cmap="YlGnBu", annot=True)
plt.title("Heatmap for correlation matrix")
plt.show()

# %%
# Pairplot to visualize relationships between variables
sns.pairplot(df, hue=None, diag_kind="hist")
plt.show()
